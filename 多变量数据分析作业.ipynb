# %%
import mytools
import pandas as pd

# %%
数据表 = mytools.读取SPSS数据文件(R'data\国家认同数据清理后.sav')

# %%
# 创建年级、政治面貌和会打多少分的交互表
cross_tab = pd.crosstab(index=[数据表['年级'], 数据表['中国传统文化']], 
                        columns=数据表['政治面貌'], 
                        margins=True, normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌                 团员        党员        群众        其他       All
# 年级  中国传统文化
# 预科  比较肯定       0.006418  0.000000  0.001284  0.000000  0.007702
#     富有内涵，意义深刻  0.008986  0.000000  0.000000  0.000000  0.008986
# 大一  古板，跟不上潮流   0.003851  0.001284  0.002567  0.000000  0.007702
#     比较肯定       0.078306  0.000000  0.007702  0.001284  0.087291
#     富有内涵，意义深刻  0.209243  0.014121  0.023107  0.002567  0.249037
# 大二  古板，跟不上潮流   0.002567  0.001284  0.003851  0.000000  0.007702
#     比较肯定       0.071887  0.003851  0.006418  0.001284  0.083440
#     富有内涵，意义深刻  0.170732  0.029525  0.023107  0.005135  0.228498
# 大三  古板，跟不上潮流   0.003851  0.001284  0.002567  0.000000  0.007702
#     比较肯定       0.032092  0.012837  0.010270  0.002567  0.057766
#     富有内涵，意义深刻  0.075738  0.042362  0.015404  0.007702  0.141207
# 大四  古板，跟不上潮流   0.002567  0.000000  0.001284  0.000000  0.003851
#     比较肯定       0.015404  0.011553  0.002567  0.000000  0.029525
#     富有内涵，意义深刻  0.055199  0.014121  0.010270  0.000000  0.079589
# All            0.736842  0.132221  0.110398  0.020539  1.000000

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = "大一"

# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['中国传统文化'], df_specific_grade['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 10.415832745206039 0.10819765233695987
# 政治面貌        团员  党员  群众  其他
# 中国传统文化
# 古板，跟不上潮流     3   1   2   0
# 比较肯定        61   0   6   1
# 富有内涵，意义深刻  163  11  18   2

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'政治面貌','中国传统文化')
# Out:
# tau_y系数: 0.0135 极弱相关或无相关
# ----  -  --  ---
# 团员  3  61  163
# 党员  1   0   11
# 群众  2   6   18
# 其他  0   1    2
# ----  -  --  ---
# 卡方值： 10.42, p值: 0.1082,自由度:6。
# 接受虚无假设
